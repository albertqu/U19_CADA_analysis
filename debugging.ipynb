# %%
from modeling import *
from behaviors import *
from peristimulus import *
import seaborn as sns

# %%
folder = "/Users/albertqu/Documents/7.Research/Wilbrecht_Lab/CADA_data/ProbSwitch_FP_data_new"
animal, session = "A2A-15B-B_RT", "p153_FP_LH"
files = encode_to_filename(folder, animal, session, ['processed'])
hfile = h5py.File(files)

# %%
class BehaviorMat:

    code_map = {1: ('center_in', 'center_in'),
                11: ('center_in', 'initiate'),
                2: ('center_out', 'center_out'),
                3: ('side_in', 'left'),
                4: ('side_out', 'left'),
                44: ('side_out', 'left'),
                5: ('side_in', 'right'),
                6: ('side_out', 'right'),
                66: ('side_out', 'right'),
                71.1: ('outcome', 'correct_unrewarded'),
                71.2: ('outcome', 'correct_rewarded'),
                72: ('outcome', 'incorrect_unrewarded'),
                73: ('outcome', 'missed'),  # saliency questionable
                74: ('outcome', 'abort')}  # saliency questionable

    # Always use efficient coding
    def __init__(self, animal, session, hfile, tau=np.inf):
        self.tau = tau
        self.animal = animal
        self.session = session
        if isinstance(hfile, str):
            print("For pipeline loaded hdf5 is recommended for performance")
            hfile = h5py.File(hfile, 'r')
        self.choice_sides = None
        self.exp_complexity = None  # Whether the ITI is complex (first round only analysis simple trials)
        self.struct_complexity = None
        self.trialN = 0
        self.hemisphere, self.region = None, None
        self.event_list = EventNode(None, None, None, None)
        self.initialize(hfile)

    def __str__(self):
        return f"BehaviorMat({self.animal}_{self.session}, tau={self.tau})"

    def initialize(self, hfile):
        self.hemisphere = 'right' if np.array(hfile["out/notes/hemisphere"]).item() else 'left'
        self.region = 'NAc' if np.array(hfile['out/notes/region']).item() else 'DMS'
        trialN = len(hfile['out/value/outcome'])
        self.trialN = trialN
        self.choice_sides = np.full(trialN, '', dtype='<U6')
        self.exp_complexity = np.full(trialN, True, dtype=bool) # default true detect back to back
        self.struct_complexity = np.full(trialN, False, dtype=bool) # default false detect double centers
        self.exp_complexity[0] = False
#         dup = {'correct_unrewarded': 0, 'correct_rewarded': 0, 'incorrect_unrewarded': 0, 
#                'missed': 0, 'abort': 0}
#         ndup = {'correct_unrewarded': 0, 'correct_rewarded': 0, 'incorrect_unrewarded': 0, 
#                'missed': 0, 'abort': 0}
#         self.struct_complexity[0] = False
        trial_event_mat = np.array(hfile['out/value/trial_event_mat'])

        # Parsing LinkedList
        prev_node = None
        # TODO: Careful of the 0.5 trial events
        for i in range(trial_event_mat.shape[0]):
            eventcode, etime, trial = trial_event_mat[i, :]
            old_eventcode = eventcode
            if eventcode == 44 or eventcode == 66:
                eventcode = eventcode // 10
            ctrial = int(np.ceil(trial))-1
            event, opt = BehaviorMat.code_map[eventcode]
#             if i % 1000 == 0:
#                 print(i, eventcode, old_eventcode, etime, trial, ctrial, event, opt)
            makenew = True

            if prev_node is not None:
                if eventcode > 70:
                    lat = prev_node.MLAT if eventcode < 73 else ""
                    self.choice_sides[ctrial] = lat
                    if prev_node.event == 'side_in':
                        prev_node.saliency = 'choice'
#                     if prev_node.etime == etime:
#                         dup[opt] += 1
#                     else:
#                         ndup[opt] += 1
                        #print('highlight', i, eventcode, etime, trial, prev_node.etime, prev_node.ecode)
                if prev_node.etime == etime:
                    if eventcode == prev_node.ecode:
                        makenew = False
                    elif eventcode < 70:
                        print(f"Warning! Duplicate timestamps({prev_node.ecode}, {eventcode}) in {str(self)}")
                    elif eventcode != 72:
                        print(f"Special Event Duplicate: {self.animal}, {self.session}, ", event, opt)
                elif eventcode == 72:
                    print(f"Unexpected non-duplicate for {trial}, {opt}, {self.animal}, {self.session}")
            else:
                assert eventcode < 70, 'outcome cannot be the first node'
            if makenew:
                # potentially fill out all properties here; then make merge an inheriting process
                evnode = self.event_list.append(event, etime, trial, eventcode)
                # Filling MLAT for side ports, Saliency for outcome and initiate
                if event == 'outcome':
                    assert self.choice_sides[ctrial] == prev_node.MLAT
                    evnode.MLAT = prev_node.MLAT
                if eventcode > 6:
                    evnode.saliency = opt
                elif eventcode > 2:
                    evnode.MLAT = opt
                prev_node = evnode
        # temporal adjacency merge
        assert not self.event_list.is_empty()
        curr_node = self.event_list.next
        while not curr_node.sentinel:
            if '_out' in curr_node.event:
                # COULD do an inner loop to make it look more straightforward
                next_node = curr_node.next
                prev_check = curr_node.prev
                if next_node.sentinel:
                    print(f"Weird early termination with port_out?! {str(curr_node)}")
                # TODO: sanity check: choice side_in does not have any mergeable port before them.
#                 print(curr_node.ecode, next_node.ecode, curr_node.etime, next_node.etime)
                if (next_node.ecode == curr_node.ecode-1) and (next_node.etime - curr_node.etime < self.tau):
                    merge_node = next_node.next
                    if merge_node.sentinel:
                        print(f"Weird early termination with port_in?! {str(next_node)}")
                    assert merge_node.ecode == curr_node.ecode, f"side in results in {str(merge_node)}"
                    merge_node.merged = True
                    self.event_list.remove_node(curr_node)
                    self.event_list.remove_node(next_node)
                    assert prev_check.next is merge_node and merge_node.prev is prev_check, "Data Structure BUG"
                    curr_node = prev_check  # jump back to previous node

            # Mark features so far saliency: only choice/outcome/initiate, MLAT: outcome/side_port
            if not curr_node.next.merged: # only trigger at "boundary events"
                # Make sure this is not a revisit due to merge
                prev_node = curr_node.prev
                next_node = curr_node.next
                if curr_node.event == 'center_in':
                    # just need MLAT
                    if prev_node.event == 'side_out':
                        curr_node.MLAT = prev_node.MLAT
                    # update structural complexity
                    if curr_node.saliency == 'initiate':
                        breakflag = False
                        cursor = curr_node.prev
                        while (not cursor.sentinel) and (cursor.event != 'outcome'):
                            if cursor.event == 'center_in':
                                self.struct_complexity[curr_node.trial_index()] = True
                                breakflag = True
                                break
                            cursor = cursor.prev
                        if not breakflag and cursor.MLAT:
                            assert (cursor.sentinel) or (cursor.next.event == 'side_out'), f"weird {cursor}, {cursor.next}"
                elif curr_node.event == 'center_out':
                    if next_node.event == 'side_in':
                        curr_node.MLAT = next_node.MLAT
                    if next_node.saliency == 'choice':
                        # assume "execution" is at center_out, recognizing that well trained animal might
                        # already have executed a program from side_out (denote side port using first/last)
                        curr_node.saliency = 'execution'
                elif curr_node.event == 'side_out':
                    sals = []
                    # TODO: with different TAU we might not want the first side out as salient event
                    if prev_node.event == 'outcome':
                        sals.append('first')
                    if next_node.event == 'center_in':
                        safe_last = True
                        cursor = next_node
                        print(curr_node.trial_index(), cursor.event, cursor.saliency)
                        while cursor.saliency != 'initiate':
                            print(cursor.event, cursor.saliency)
                            if cursor.sentinel:
                                print(f"Weird early termination with port_out?! {str(cursor.prev)}")
                            if cursor.event == 'side_in':
                                safe_last = False
                                break
                            cursor = cursor.next
                        print(curr_node.trial_index(), cursor.event, cursor.saliency, safe_last)
                        if safe_last:
                            sals.append('last')
                    curr_node.saliency = "_".join(sals)
                    if len(sals) == 2:
                        print(str(curr_node.prev), str(curr_node), str(curr_node.next))
                        self.exp_complexity[int(curr_node.trial)] = False
            curr_node = curr_node.next

    def get_event_times(self, event, simple=True, saliency=True):
        curr = self.event_list.next
        event_times = []
        trials = []
        sals = None
        if saliency and 'side_out' in event:
            event, sals = event.split("__")
        else:
            salmap = {'center_in': 'initiate',
                      'center_out': 'execution',
                      'side_out': 'choice',
                      'outcome': ['correct_unrewarded', 'correct_rewarded', 'incorrect_unrewarded']}
            sals = salmap[event]

        while not curr.sentinel:
            if curr.event == event:
                complex_check = True
                cti = curr.trial_index()
                if simple and event in ['center_in', 'side_out'] and \
                        (self.exp_complexity[cti] or self.struct_complexity[cti]):
                    complex_check = False

                if (not saliency) or (curr.saliency is not None and curr.saliency in sals) \
                        and complex_check:
                    event_times.append(curr.etime)
                    trials.append(curr.trial_index())
        event_times = np.array(event_times)
        trials = np.array(trials)
        if saliency:
            if simple:
                assert len(event_times) == np.sum(self.exp_complexity)
            else:
                assert len(event_times) == self.trialN
        return event_times, trials

    def get_trial_features(self):
        pass

    def get_inter_trial_stats(self, option='MT'):
        """
        :param option:
            'MT': movement times (vigor)
            'ITI_full': full ITI for decay
            'MT_full': movement times
        :return:
        """
        side_out_firsts, _ = self.get_event_times('side_out__first', False, True)
        initiates, _ = self.get_event_times('center_in', False, True)
        outcomes, _ = self.get_event_times('outcome', False, True)
        #
        if option == 'MT_full':
            results = initiates - side_out_firsts
        elif option == 'ITI_full':
            results = np.zeros(self.trialN)
            results[1:] = initiates[1:] - outcomes[:-1]
        else:
            raise NotImplementedError(f"{option} not implemented")
        return results


class EventNode:
    def __init__(self, event, etime, trial, ecode):
        self.event = event
        self.trial = trial
        self.etime = etime
        self.ecode = ecode # For debug purpose
        # Use "" for Null
        self.MLAT = ""
        #self.OLAT = "" OLAT should be more dynamic
        self.saliency = ""
        self.merged = False
        self.next = None
        self.prev = None
        if event is None:
            # Implements a circular LinkedList
            self.sentinel = True
            self.next = self
            self.prev = self
            self.size = 0
        else:
            self.sentinel = False

    def mvmt_dynamic(self):
        pass

    def trial_index(self):
        # 0.5 is ITI but considered in trial 0
        return int(np.ceil(self.trial)) - 1

    def __str__(self):
        return f"EventNode({self.event}, {self.trial}, {self.etime:.1f}ms, {self.ecode})"

    # Methods Reserved For Sentinel Node
    def __len__(self):
        assert self.sentinel, 'must be sentinel node to do this'
        return self.size

    def append(self, event, etime, trial, ecode):
        assert self.sentinel, 'must be sentinel node to do this'
        evn = EventNode(event, etime, trial, ecode)
        old_end = self.prev
        assert old_end.next is self, "what is happening"
        old_end.next = evn
        evn.prev = old_end
        self.prev = evn
        evn.next = self
        self.size += 1
        return evn

    def prepend(self):
        # Not important
        assert self.sentinel, 'must be sentinel node to do this'
        pass

    def remove_node(self, node):
        assert self.sentinel, 'must be sentinel node to do this'
        assert self.size, 'list must be non-empty'
        next_node = node.next
        prev_node = node.prev
        prev_node.next = next_node
        next_node.prev = prev_node
        node.next = None
        node.prev = None
        self.size -= 1

    def get_last(self):
        assert self.sentinel, 'must be sentinel node to do this'
        return self.prev

    def get_first(self):
        assert self.sentinel, 'must be sentinel node to do this'
        return self.next

    def is_empty(self):
        assert self.sentinel, 'must be sentinel node to do this'
        return self.size == 0

# %%
trial_event_mat.shape
# Out:
# (10365, 3)

# %%
bmat = BehaviorMat(animal, session, hfile)
# bmat.initialize(hfile)
# Out:
# 0 center_in initiate
# 0 center_in initiate True
# 1 center_in initiate
# 1 center_in initiate True
# EventNode(outcome, 1.0, 41464.4ms, 71.2) EventNode(side_out, 1.5, 43853.6ms, 4.0) EventNode(center_in, 2.0, 44417.5ms, 11.0)
# 2 center_in initiate
# 2 center_in initiate True
# EventNode(outcome, 2.0, 44868.5ms, 71.2) EventNode(side_out, 2.5, 50770.5ms, 4.0) EventNode(center_in, 3.0, 51219.0ms, 11.0)
# 3 center_in initiate
# 3 center_in initiate True
# EventNode(outcome, 3.0, 51624.5ms, 71.2) EventNode(side_out, 3.5, 52900.0ms, 4.0) EventNode(center_in, 4.0, 54265.6ms, 11.0)
# 4 center_in initiate
# 4 center_in initiate True
# EventNode(outcome, 4.0, 54770.6ms, 71.2) EventNode(side_out, 4.5, 55367.1ms, 4.0) EventNode(center_in, 5.0, 55706.1ms, 11.0)
# 5 center_in initiate
# 5 center_in initiate True
# EventNode(outcome, 5.0, 56168.6ms, 71.2) EventNode(side_out, 5.5, 56797.6ms, 4.0) EventNode(center_in, 6.0, 57228.6ms, 11.0)
# 6 center_in
# center_in
# center_out
# side_in
# 6 side_in  False
# NO bueno
# 6 center_in initiate
# 6 center_in initiate True
# 7 center_in initiate
# 7 center_in initiate True
# 8 center_in initiate
# 8 center_in initiate True
# EventNode(outcome, 8.0, 94344.1ms, 71.2) EventNode(side_out, 8.5, 97957.1ms, 4.0) EventNode(center_in, 9.0, 98582.6ms, 11.0)
# 9 center_in initiate
# 9 center_in initiate True
# EventNode(outcome, 9.0, 98990.1ms, 71.2) EventNode(side_out, 9.5, 101175.6ms, 4.0) EventNode(center_in, 10.0, 101608.1ms, 11.0)
# 10 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 10 side_in  False
# NO bueno
# 10 center_in initiate
# 10 center_in initiate True
# 11 center_in
# center_in
# center_out
# center_in
# center_out
# 11 center_in initiate True
# EventNode(outcome, 11.0, 108971.9ms, 72.0) EventNode(side_out, 11.5, 109465.9ms, 6.0) EventNode(center_in, 11.5, 109879.4ms, 1.0)
# 12 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 12 side_in  False
# NO bueno
# 12 center_in initiate
# 12 center_in initiate True
# 13 center_in initiate
# 13 center_in initiate True
# EventNode(outcome, 13.0, 168243.0ms, 71.2) EventNode(side_out, 13.5, 171702.2ms, 4.0) EventNode(center_in, 14.0, 172597.1ms, 11.0)
# 14 center_in initiate
# 14 center_in initiate True
# EventNode(outcome, 14.0, 173067.1ms, 71.2) EventNode(side_out, 14.5, 175849.9ms, 4.0) EventNode(center_in, 15.0, 178493.2ms, 11.0)
# 15 center_in initiate
# 15 center_in initiate True
# EventNode(outcome, 15.0, 179010.2ms, 71.2) EventNode(side_out, 15.5, 181165.7ms, 4.0) EventNode(center_in, 16.0, 181696.7ms, 11.0)
# 16 center_in initiate
# 16 center_in initiate True
# EventNode(outcome, 16.0, 182489.3ms, 71.2) EventNode(side_out, 16.5, 185277.8ms, 4.0) EventNode(center_in, 17.0, 185822.3ms, 11.0)
# 17 center_in initiate
# 17 center_in initiate True
# EventNode(outcome, 17.0, 186346.3ms, 71.2) EventNode(side_out, 17.5, 187843.8ms, 4.0) EventNode(center_in, 18.0, 188419.8ms, 11.0)
# 18 center_in initiate
# 18 center_in initiate True
# EventNode(outcome, 18.0, 188987.3ms, 71.2) EventNode(side_out, 18.5, 191318.8ms, 4.0) EventNode(center_in, 19.0, 191893.8ms, 11.0)
# 19 center_in
# center_in
# center_out
# side_in
# 19 side_in  False
# NO bueno
# 19 center_in initiate
# 19 center_in initiate True
# 20 center_in initiate
# 20 center_in initiate True
# EventNode(outcome, 20.0, 195408.4ms, 71.2) EventNode(side_out, 20.5, 197609.9ms, 4.0) EventNode(center_in, 21.0, 197998.5ms, 11.0)
# 21 center_in initiate
# 21 center_in initiate True
# EventNode(outcome, 21.0, 198541.5ms, 71.2) EventNode(side_out, 21.5, 200750.3ms, 4.0) EventNode(center_in, 22.0, 201173.6ms, 11.0)
# 22 center_in initiate
# 22 center_in initiate True
# EventNode(outcome, 22.0, 201705.5ms, 71.2) EventNode(side_out, 22.5, 203890.2ms, 4.0) EventNode(center_in, 23.0, 204503.3ms, 11.0)
# 23 center_in initiate
# 23 center_in initiate True
# EventNode(outcome, 23.0, 205066.9ms, 72.0) EventNode(side_out, 23.5, 205738.5ms, 4.0) EventNode(center_in, 24.0, 207071.6ms, 11.0)
# 24 center_in initiate
# 24 center_in initiate True
# EventNode(outcome, 24.0, 207690.2ms, 72.0) EventNode(side_out, 24.5, 207968.8ms, 4.0) EventNode(center_in, 25.0, 210197.5ms, 11.0)
# 25 center_in initiate
# 25 center_in initiate True
# EventNode(outcome, 25.0, 212639.4ms, 71.2) EventNode(side_out, 25.5, 214463.6ms, 6.0) EventNode(center_in, 26.0, 214963.6ms, 11.0)
# 26 center_in initiate
# 26 center_in initiate True
# EventNode(outcome, 26.0, 215354.2ms, 71.2) EventNode(side_out, 26.5, 217474.5ms, 6.0) EventNode(center_in, 27.0, 217986.0ms, 11.0)
# 27 center_in initiate
# 27 center_in initiate True
# EventNode(outcome, 27.0, 218326.1ms, 71.2) EventNode(side_out, 27.5, 220481.9ms, 6.0) EventNode(center_in, 28.0, 221011.9ms, 11.0)
# 28 center_in initiate
# 28 center_in initiate True
# EventNode(outcome, 28.0, 221349.0ms, 71.2) EventNode(side_out, 28.5, 224283.3ms, 6.0) EventNode(center_in, 29.0, 224812.4ms, 11.0)
# 29 center_in initiate
# 29 center_in initiate True
# EventNode(outcome, 29.0, 225168.4ms, 71.2) EventNode(side_out, 29.5, 227380.2ms, 6.0) EventNode(center_in, 30.0, 228490.9ms, 11.0)
# 30 center_in initiate
# 30 center_in initiate True
# EventNode(outcome, 30.0, 228945.4ms, 71.2) EventNode(side_out, 30.5, 230830.7ms, 6.0) EventNode(center_in, 31.0, 231300.2ms, 11.0)
# 31 center_in initiate
# 31 center_in initiate True
# EventNode(outcome, 31.0, 231674.8ms, 71.2) EventNode(side_out, 31.5, 233651.0ms, 6.0) EventNode(center_in, 32.0, 234322.6ms, 11.0)
# 32 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 32 side_in  False
# NO bueno
# 32 center_in initiate
# 32 center_in initiate True
# 33 center_in
# center_in
# center_out
# 33 center_in initiate True
# 34 center_in initiate
# 34 center_in initiate True
# EventNode(outcome, 34.0, 259628.8ms, 71.2) EventNode(side_out, 34.5, 261981.6ms, 6.0) EventNode(center_in, 35.0, 262420.7ms, 11.0)
# 35 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 35 side_in  False
# NO bueno
# 35 center_in initiate
# 35 center_in initiate True
# 36 center_in initiate
# 36 center_in initiate True
# EventNode(outcome, 36.0, 266179.2ms, 71.1) EventNode(side_out, 36.5, 266906.8ms, 4.0) EventNode(center_in, 37.0, 267539.8ms, 11.0)
# 37 center_in initiate
# 37 center_in initiate True
# EventNode(outcome, 37.0, 268105.4ms, 71.2) EventNode(side_out, 37.5, 270165.8ms, 4.0) EventNode(center_in, 38.0, 270726.4ms, 11.0)
# 38 center_in initiate
# 38 center_in initiate True
# EventNode(outcome, 38.0, 271236.5ms, 71.2) EventNode(side_out, 38.5, 273205.1ms, 4.0) EventNode(center_in, 39.0, 273690.6ms, 11.0)
# 39 center_in initiate
# 39 center_in initiate True
# EventNode(outcome, 39.0, 274540.4ms, 71.2) EventNode(side_out, 39.5, 276416.9ms, 4.0) EventNode(center_in, 40.0, 276879.5ms, 11.0)
# 40 center_in initiate
# 40 center_in initiate True
# EventNode(outcome, 40.0, 277333.5ms, 71.2) EventNode(side_out, 40.5, 280343.0ms, 4.0) EventNode(center_in, 41.0, 280894.5ms, 11.0)
# 41 center_in initiate
# 41 center_in initiate True
# EventNode(outcome, 41.0, 281374.5ms, 71.2) EventNode(side_out, 41.5, 283293.7ms, 4.0) EventNode(center_in, 42.0, 283799.2ms, 11.0)
# 42 center_in initiate
# 42 center_in initiate True
# EventNode(outcome, 42.0, 284269.6ms, 71.2) EventNode(side_out, 42.5, 286412.1ms, 4.0) EventNode(center_in, 43.0, 286846.6ms, 11.0)
# 43 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 43 side_in  False
# NO bueno
# 43 center_in initiate
# 43 center_in initiate True
# 44 center_in
# center_in
# center_out
# side_in
# 44 side_in  False
# NO bueno
# 44 center_in initiate
# 44 center_in initiate True
# 45 center_in
# center_in
# center_out
# side_in
# 45 side_in  False
# NO bueno
# 45 center_in initiate
# 45 center_in initiate True
# 46 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 46 side_in  False
# NO bueno
# 46 center_in initiate
# 46 center_in initiate True
# 47 center_in initiate
# 47 center_in initiate True
# 48 center_in
# center_in
# center_out
# side_in
# 48 side_in  False
# NO bueno
# 48 center_in initiate
# 48 center_in initiate True
# 49 center_in initiate
# 49 center_in initiate True
# 50 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 50 side_in  False
# NO bueno
# 50 center_in initiate
# 50 center_in initiate True
# 51 center_in
# center_in
# center_out
# center_in
# center_out
# 51 center_in initiate True
# EventNode(outcome, 51.0, 372040.3ms, 72.0) EventNode(side_out, 51.5, 372223.3ms, 6.0) EventNode(center_in, 51.5, 372620.3ms, 1.0)
# 52 center_in initiate
# 52 center_in initiate True
# EventNode(outcome, 52.0, 374428.8ms, 71.2) EventNode(side_out, 52.5, 380305.5ms, 4.0) EventNode(center_in, 53.0, 380702.0ms, 11.0)
# 53 center_in initiate
# 53 center_in initiate True
# EventNode(outcome, 53.0, 381149.9ms, 71.2) EventNode(side_out, 53.5, 383162.1ms, 4.0) EventNode(center_in, 54.0, 383568.5ms, 11.0)
# 54 center_in initiate
# 54 center_in initiate True
# EventNode(outcome, 54.0, 384313.9ms, 71.2) EventNode(side_out, 54.5, 386952.3ms, 4.0) EventNode(center_in, 55.0, 387421.8ms, 11.0)
# 55 center_in initiate
# 55 center_in initiate True
# EventNode(outcome, 55.0, 387864.9ms, 71.2) EventNode(side_out, 55.5, 390307.2ms, 4.0) EventNode(center_in, 56.0, 390701.1ms, 11.0)
# 56 center_in initiate
# 56 center_in initiate True
# EventNode(outcome, 56.0, 391229.0ms, 71.2) EventNode(side_out, 56.5, 393388.8ms, 4.0) EventNode(center_in, 57.0, 394025.9ms, 11.0)
# 57 center_in initiate
# 57 center_in initiate True
# EventNode(outcome, 57.0, 394543.0ms, 71.2) EventNode(side_out, 57.5, 396760.3ms, 4.0) EventNode(center_in, 58.0, 397179.8ms, 11.0)
# 58 center_in
# center_in
# center_out
# center_in
# center_out
# 58 center_in initiate True
# EventNode(outcome, 58.0, 397858.8ms, 71.1) EventNode(side_out, 58.5, 398272.7ms, 4.0) EventNode(center_in, 58.5, 398671.2ms, 1.0)
# 59 center_in initiate
# 59 center_in initiate True
# EventNode(outcome, 59.0, 401077.1ms, 71.2) EventNode(side_out, 59.5, 403364.6ms, 4.0) EventNode(center_in, 60.0, 403757.6ms, 11.0)
# 60 center_in
# center_in
# center_out
# side_in
# 60 side_in  False
# NO bueno
# 60 center_in initiate
# 60 center_in initiate True
# 61 center_in initiate
# 61 center_in initiate True
# EventNode(outcome, 61.0, 412615.2ms, 71.2) EventNode(side_out, 61.5, 414810.4ms, 4.0) EventNode(center_in, 62.0, 415365.8ms, 11.0)
# 62 center_in initiate
# 62 center_in initiate True
# EventNode(outcome, 62.0, 415916.3ms, 71.2) EventNode(side_out, 62.5, 418212.0ms, 4.0) EventNode(center_in, 63.0, 419003.9ms, 11.0)
# 63 center_in initiate
# 63 center_in initiate True
# EventNode(outcome, 63.0, 419506.4ms, 71.2) EventNode(side_out, 63.5, 421756.9ms, 4.0) EventNode(center_in, 64.0, 422551.4ms, 11.0)
# 64 center_in initiate
# 64 center_in initiate True
# EventNode(outcome, 64.0, 423072.4ms, 71.2) EventNode(side_out, 64.5, 425292.4ms, 4.0) EventNode(center_in, 65.0, 425680.3ms, 11.0)
# 65 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 65 side_in  False
# NO bueno
# 65 center_in initiate
# 65 center_in initiate True
# 66 center_in
# center_in
# center_out
# side_in
# 66 side_in  False
# NO bueno
# 66 center_in initiate
# 66 center_in initiate True
# 67 center_in initiate
# 67 center_in initiate True
# EventNode(outcome, 67.0, 435346.8ms, 72.0) EventNode(side_out, 67.5, 463263.0ms, 6.0) EventNode(center_in, 68.0, 463601.5ms, 11.0)
# 68 center_in
# center_in
# center_out
# 68 center_in initiate True
# EventNode(outcome, 68.0, 464147.0ms, 71.2) EventNode(side_out, 68.5, 466465.0ms, 4.0) EventNode(center_in, 68.5, 467103.5ms, 1.0)
# 69 center_in
# center_in
# center_out
# side_in
# 69 side_in  False
# NO bueno
# 69 center_in initiate
# 69 center_in initiate True
# 70 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 70 side_in  False
# NO bueno
# 70 center_in initiate
# 70 center_in initiate True
# 71 center_in initiate
# 71 center_in initiate True
# EventNode(outcome, 71.0, 474968.0ms, 71.2) EventNode(side_out, 71.5, 476409.8ms, 4.0) EventNode(center_in, 72.0, 476889.9ms, 11.0)
# 72 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 72 side_in  False
# NO bueno
# 72 center_in initiate
# 72 center_in initiate True
# 73 center_in initiate
# 73 center_in initiate True
# 74 center_in
# center_in
# center_out
# 74 center_in initiate True
# EventNode(outcome, 74.0, 515570.1ms, 71.1) EventNode(side_out, 74.5, 516051.2ms, 4.0) EventNode(center_in, 74.5, 516450.2ms, 1.0)
# 75 center_in initiate
# 75 center_in initiate True
# EventNode(outcome, 75.0, 521290.7ms, 71.2) EventNode(side_out, 75.5, 525243.8ms, 4.0) EventNode(center_in, 76.0, 525641.7ms, 11.0)
# 76 center_in initiate
# 76 center_in initiate True
# EventNode(outcome, 76.0, 526122.7ms, 71.2) EventNode(side_out, 76.5, 527242.7ms, 4.0) EventNode(center_in, 77.0, 527722.2ms, 11.0)
# 77 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 77 side_in  False
# NO bueno
# 77 center_in initiate
# 77 center_in initiate True
# 78 center_in initiate
# 78 center_in initiate True
# EventNode(outcome, 78.0, 531714.1ms, 71.2) EventNode(side_out, 78.5, 533080.5ms, 6.0) EventNode(center_in, 79.0, 533505.0ms, 11.0)
# 79 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 79 side_in  False
# NO bueno
# 79 center_in initiate
# 79 center_in initiate True
# 80 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 80 side_in  False
# NO bueno
# 80 center_in initiate
# 80 center_in initiate True
# 81 center_in initiate
# 81 center_in initiate True
# 82 center_in
# center_in
# center_out
# side_in
# 82 side_in  False
# NO bueno
# 82 center_in initiate
# 82 center_in initiate True
# 83 center_in
# center_in
# center_out
# side_in
# 83 side_in  False
# NO bueno
# 83 center_in initiate
# 83 center_in initiate True
# 84 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 84 side_in  False
# NO bueno
# 84 center_in initiate
# 84 center_in initiate True
# 85 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# 85 center_in initiate True
# EventNode(outcome, 85.0, 610811.1ms, 71.1) EventNode(side_out, 85.5, 611315.1ms, 6.0) EventNode(center_in, 85.5, 612197.6ms, 1.0)
# 86 center_in initiate
# 86 center_in initiate True
# EventNode(outcome, 86.0, 612870.6ms, 71.2) EventNode(side_out, 86.5, 616888.0ms, 6.0) EventNode(center_in, 87.0, 617359.5ms, 11.0)
# 87 center_in initiate
# 87 center_in initiate True
# EventNode(outcome, 87.0, 617753.0ms, 71.2) EventNode(side_out, 87.5, 620482.9ms, 6.0) EventNode(center_in, 88.0, 620976.4ms, 11.0)
# 88 center_in initiate
# 88 center_in initiate True
# EventNode(outcome, 88.0, 621349.9ms, 71.2) EventNode(side_out, 88.5, 622614.9ms, 6.0) EventNode(center_in, 89.0, 623070.8ms, 11.0)
# 89 center_in initiate
# 89 center_in initiate True
# EventNode(outcome, 89.0, 623484.8ms, 71.2) EventNode(side_out, 89.5, 625175.3ms, 6.0) EventNode(center_in, 90.0, 625616.8ms, 11.0)
# 90 center_in initiate
# 90 center_in initiate True
# EventNode(outcome, 90.0, 626042.8ms, 71.2) EventNode(side_out, 90.5, 628699.2ms, 6.0) EventNode(center_in, 91.0, 629197.7ms, 11.0)
# 91 center_in initiate
# 91 center_in initiate True
# EventNode(outcome, 91.0, 629638.7ms, 71.2) EventNode(side_out, 91.5, 631719.1ms, 6.0) EventNode(center_in, 92.0, 632168.1ms, 11.0)
# 92 center_in initiate
# 92 center_in initiate True
# EventNode(outcome, 92.0, 632624.6ms, 71.2) EventNode(side_out, 92.5, 635000.0ms, 6.0) EventNode(center_in, 93.0, 635459.0ms, 11.0)
# 93 center_in
# center_in
# center_out
# 93 center_in initiate True
# EventNode(outcome, 93.0, 635892.0ms, 71.2) EventNode(side_out, 93.5, 638875.0ms, 6.0) EventNode(center_in, 93.5, 639516.9ms, 1.0)
# 94 center_in initiate
# 94 center_in initiate True
# EventNode(outcome, 94.0, 640495.9ms, 71.2) EventNode(side_out, 94.5, 642662.4ms, 6.0) EventNode(center_in, 95.0, 643190.9ms, 11.0)
# 95 center_in initiate
# 95 center_in initiate True
# EventNode(outcome, 95.0, 643674.3ms, 71.2) EventNode(side_out, 95.5, 646422.3ms, 6.0) EventNode(center_in, 96.0, 646909.3ms, 11.0)
# 96 center_in initiate
# 96 center_in initiate True
# EventNode(outcome, 96.0, 647342.7ms, 71.2) EventNode(side_out, 96.5, 649819.7ms, 6.0) EventNode(center_in, 97.0, 650397.2ms, 11.0)
# 97 center_in
# center_in
# center_out
# side_in
# 97 side_in  False
# NO bueno
# 97 center_in initiate
# 97 center_in initiate True
# 98 center_in initiate
# 98 center_in initiate True
# EventNode(outcome, 98.0, 653781.1ms, 71.2) EventNode(side_out, 98.5, 656434.5ms, 6.0) EventNode(center_in, 99.0, 657072.0ms, 11.0)
# 99 center_in
# center_in
# center_out
# side_in
# 99 side_in  False
# NO bueno
# 99 center_in initiate
# 99 center_in initiate True
# 100 center_in initiate
# 100 center_in initiate True
# EventNode(outcome, 100.0, 660247.4ms, 71.2) EventNode(side_out, 100.5, 662665.9ms, 6.0) EventNode(center_in, 101.0, 663125.9ms, 11.0)
# 101 center_in initiate
# 101 center_in initiate True
# EventNode(outcome, 101.0, 663556.4ms, 71.2) EventNode(side_out, 101.5, 666484.8ms, 6.0) EventNode(center_in, 102.0, 666989.8ms, 11.0)
# 102 center_in
# center_in
# center_out
# 102 center_in initiate True
# EventNode(outcome, 102.0, 667544.3ms, 72.0) EventNode(side_out, 102.5, 668191.7ms, 6.0) EventNode(center_in, 102.5, 668675.2ms, 1.0)
# 103 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 103 side_in  False
# NO bueno
# 103 center_in initiate
# 103 center_in initiate True
# 104 center_in initiate
# 104 center_in initiate True
# 105 center_in initiate
# 105 center_in initiate True
# EventNode(outcome, 105.0, 686425.8ms, 71.2) EventNode(side_out, 105.5, 687544.1ms, 4.0) EventNode(center_in, 106.0, 687940.2ms, 11.0)
# 106 center_in initiate
# 106 center_in initiate True
# EventNode(outcome, 106.0, 688668.0ms, 71.2) EventNode(side_out, 106.5, 690936.1ms, 4.0) EventNode(center_in, 107.0, 691617.0ms, 11.0)
# 107 center_in initiate
# 107 center_in initiate True
# EventNode(outcome, 107.0, 692004.9ms, 71.2) EventNode(side_out, 107.5, 693631.5ms, 4.0) EventNode(center_in, 108.0, 694368.5ms, 11.0)
# 108 center_in initiate
# 108 center_in initiate True
# EventNode(outcome, 108.0, 694817.0ms, 71.2) EventNode(side_out, 108.5, 697115.0ms, 4.0) EventNode(center_in, 109.0, 697610.5ms, 11.0)
# 109 center_in
# center_in
# center_out
# side_in
# 109 side_in  False
# NO bueno
# 109 center_in initiate
# 109 center_in initiate True
# 110 center_in initiate
# 110 center_in initiate True
# EventNode(outcome, 110.0, 702819.0ms, 71.2) EventNode(side_out, 110.5, 704948.2ms, 4.0) EventNode(center_in, 111.0, 705353.2ms, 11.0)
# 111 center_in initiate
# 111 center_in initiate True
# EventNode(outcome, 111.0, 705876.1ms, 71.2) EventNode(side_out, 111.5, 707870.1ms, 4.0) EventNode(center_in, 112.0, 708389.6ms, 11.0)
# 112 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 112 side_in  False
# NO bueno
# 112 center_in initiate
# 112 center_in initiate True
# 113 center_in initiate
# 113 center_in initiate True
# 114 center_in initiate
# 114 center_in initiate True
# EventNode(outcome, 114.0, 721734.5ms, 71.1) EventNode(side_out, 114.5, 722124.0ms, 4.0) EventNode(center_in, 115.0, 723202.5ms, 11.0)
# 115 center_in
# center_in
# center_out
# side_in
# 115 side_in  False
# NO bueno
# 115 center_in initiate
# 115 center_in initiate True
# 116 center_in
# center_in
# center_out
# side_in
# 116 side_in  False
# NO bueno
# 116 center_in initiate
# 116 center_in initiate True
# 117 center_in
# center_in
# center_out
# 117 center_in initiate True
# EventNode(outcome, 117.0, 731429.5ms, 71.1) EventNode(side_out, 117.5, 732465.0ms, 4.0) EventNode(center_in, 117.5, 732829.5ms, 1.0)
# 118 center_in initiate
# 118 center_in initiate True
# EventNode(outcome, 118.0, 733794.5ms, 71.2) EventNode(side_out, 118.5, 736077.5ms, 4.0) EventNode(center_in, 119.0, 736602.5ms, 11.0)
# 119 center_in initiate
# 119 center_in initiate True
# EventNode(outcome, 119.0, 737206.5ms, 71.2) EventNode(side_out, 119.5, 739315.0ms, 4.0) EventNode(center_in, 120.0, 739782.6ms, 11.0)
# 120 center_in
# center_in
# center_out
# center_in
# center_out
# 120 center_in initiate True
# EventNode(outcome, 120.0, 740689.1ms, 72.0) EventNode(side_out, 120.5, 741202.1ms, 4.0) EventNode(center_in, 120.5, 741729.1ms, 1.0)
# 121 center_in initiate
# 121 center_in initiate True
# EventNode(outcome, 121.0, 742514.6ms, 72.0) EventNode(side_out, 121.5, 742978.1ms, 4.0) EventNode(center_in, 122.0, 744066.1ms, 11.0)
# 122 center_in initiate
# 122 center_in initiate True
# 123 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 123 side_in  False
# NO bueno
# 123 center_in initiate
# 123 center_in initiate True
# 124 center_in
# center_in
# center_out
# 124 center_in initiate True
# EventNode(outcome, 124.0, 754649.2ms, 71.2) EventNode(side_out, 124.5, 757212.3ms, 6.0) EventNode(center_in, 124.5, 757709.3ms, 1.0)
# 125 center_in initiate
# 125 center_in initiate True
# EventNode(outcome, 125.0, 758490.3ms, 71.2) EventNode(side_out, 125.5, 761077.3ms, 6.0) EventNode(center_in, 126.0, 761594.3ms, 11.0)
# 126 center_in initiate
# 126 center_in initiate True
# EventNode(outcome, 126.0, 761956.8ms, 71.2) EventNode(side_out, 126.5, 763523.4ms, 6.0) EventNode(center_in, 127.0, 763994.4ms, 11.0)
# 127 center_in initiate
# 127 center_in initiate True
# EventNode(outcome, 127.0, 764399.4ms, 71.2) EventNode(side_out, 127.5, 764897.9ms, 6.0) EventNode(center_in, 128.0, 765716.4ms, 11.0)
# 128 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 128 side_in  False
# NO bueno
# 128 center_in initiate
# 128 center_in initiate True
# 129 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 129 side_in  False
# NO bueno
# 129 center_in initiate
# 129 center_in initiate True
# 130 center_in initiate
# 130 center_in initiate True
# EventNode(outcome, 130.0, 772315.0ms, 71.2) EventNode(side_out, 130.5, 773245.5ms, 6.0) EventNode(center_in, 131.0, 773759.5ms, 11.0)
# 131 center_in initiate
# 131 center_in initiate True
# EventNode(outcome, 131.0, 774130.0ms, 71.2) EventNode(side_out, 131.5, 777016.5ms, 6.0) EventNode(center_in, 132.0, 777510.5ms, 11.0)
# 132 center_in initiate
# 132 center_in initiate True
# EventNode(outcome, 132.0, 777880.5ms, 71.2) EventNode(side_out, 132.5, 780946.1ms, 6.0) EventNode(center_in, 133.0, 781513.6ms, 11.0)
# 133 center_in
# center_in
# center_out
# 133 center_in initiate True
# EventNode(outcome, 133.0, 781899.1ms, 71.2) EventNode(side_out, 133.5, 783876.1ms, 6.0) EventNode(center_in, 133.5, 784453.1ms, 1.0)
# 134 center_in
# center_in
# center_out
# side_in
# 134 side_in  False
# NO bueno
# 134 center_in initiate
# 134 center_in initiate True
# 135 center_in initiate
# 135 center_in initiate True
# EventNode(outcome, 135.0, 788325.7ms, 71.2) EventNode(side_out, 135.5, 790683.7ms, 6.0) EventNode(center_in, 136.0, 791167.2ms, 11.0)
# 136 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 136 side_in  False
# NO bueno
# 136 center_in initiate
# 136 center_in initiate True
# 137 center_in
# center_in
# center_out
# 137 center_in initiate True
# EventNode(outcome, 137.0, 794276.8ms, 71.1) EventNode(side_out, 137.5, 794427.3ms, 6.0) EventNode(center_in, 137.5, 795328.8ms, 1.0)
# 138 center_in initiate
# 138 center_in initiate True
# EventNode(outcome, 138.0, 796239.3ms, 71.2) EventNode(side_out, 138.5, 798582.8ms, 6.0) EventNode(center_in, 139.0, 799117.3ms, 11.0)
# 139 center_in initiate
# 139 center_in initiate True
# EventNode(outcome, 139.0, 799557.8ms, 71.2) EventNode(side_out, 139.5, 801542.9ms, 6.0) EventNode(center_in, 140.0, 802584.9ms, 11.0)
# 140 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 140 side_in  False
# NO bueno
# 140 center_in initiate
# 140 center_in initiate True
# 141 center_in
# center_in
# center_out
# side_in
# 141 side_in  False
# NO bueno
# 141 center_in initiate
# 141 center_in initiate True
# 142 center_in
# center_in
# center_out
# 142 center_in initiate True
# EventNode(outcome, 142.0, 809266.5ms, 72.0) EventNode(side_out, 142.5, 809981.5ms, 4.0) EventNode(center_in, 142.5, 810693.0ms, 1.0)
# 143 center_in
# center_in
# center_out
# side_in
# 143 side_in  False
# NO bueno
# 143 center_in initiate
# 143 center_in initiate True
# 144 center_in initiate
# 144 center_in initiate True
# EventNode(outcome, 144.0, 814893.0ms, 72.0) EventNode(side_out, 144.5, 815042.0ms, 4.0) EventNode(center_in, 145.0, 915924.8ms, 11.0)
# 145 center_in initiate
# 145 center_in initiate True
# 146 center_in
# center_in
# center_out
# side_in
# 146 side_in  False
# NO bueno
# 146 center_in initiate
# 146 center_in initiate True
# 147 center_in initiate
# 147 center_in initiate True
# EventNode(outcome, 147.0, 944777.7ms, 71.1) EventNode(side_out, 147.5, 945588.2ms, 6.0) EventNode(center_in, 148.0, 946845.7ms, 11.0)
# 148 center_in initiate
# 148 center_in initiate True
# EventNode(outcome, 148.0, 947437.8ms, 71.2) EventNode(side_out, 148.5, 952332.8ms, 6.0) EventNode(center_in, 149.0, 952741.8ms, 11.0)
# 149 center_in initiate
# 149 center_in initiate True
# EventNode(outcome, 149.0, 953150.8ms, 71.2) EventNode(side_out, 149.5, 956270.9ms, 6.0) EventNode(center_in, 150.0, 956801.4ms, 11.0)
# 150 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 150 side_in  False
# NO bueno
# 150 center_in initiate
# 150 center_in initiate True
# 151 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 151 side_in  False
# NO bueno
# 151 center_in initiate
# 151 center_in initiate True
# 152 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 152 side_in  False
# NO bueno
# 152 center_in initiate
# 152 center_in initiate True
# 153 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 153 side_in  False
# NO bueno
# 153 center_in initiate
# 153 center_in initiate True
# 154 center_in initiate
# 154 center_in initiate True
# EventNode(outcome, 154.0, 971119.6ms, 72.0) EventNode(side_out, 154.5, 971611.6ms, 6.0) EventNode(center_in, 155.0, 972742.6ms, 11.0)
# 155 center_in initiate
# 155 center_in initiate True
# 156 center_in initiate
# 156 center_in initiate True
# EventNode(outcome, 156.0, 1011530.1ms, 71.2) EventNode(side_out, 156.5, 1014373.2ms, 4.0) EventNode(center_in, 157.0, 1014918.2ms, 11.0)
# 157 center_in initiate
# 157 center_in initiate True
# EventNode(outcome, 157.0, 1015523.1ms, 71.2) EventNode(side_out, 157.5, 1018303.1ms, 4.0) EventNode(center_in, 158.0, 1018783.2ms, 11.0)
# 158 center_in initiate
# 158 center_in initiate True
# EventNode(outcome, 158.0, 1019219.2ms, 71.2) EventNode(side_out, 158.5, 1020384.7ms, 4.0) EventNode(center_in, 159.0, 1020969.2ms, 11.0)
# 159 center_in initiate
# 159 center_in initiate True
# EventNode(outcome, 159.0, 1021342.2ms, 71.2) EventNode(side_out, 159.5, 1022157.7ms, 4.0) EventNode(center_in, 160.0, 1022560.8ms, 11.0)
# 160 center_in initiate
# 160 center_in initiate True
# EventNode(outcome, 160.0, 1022998.3ms, 71.2) EventNode(side_out, 160.5, 1025470.6ms, 4.0) EventNode(center_in, 161.0, 1025862.6ms, 11.0)
# 161 center_in
# center_in
# center_out
# side_in
# 161 side_in  False
# NO bueno
# 161 center_in initiate
# 161 center_in initiate True
# 162 center_in initiate
# 162 center_in initiate True
# EventNode(outcome, 162.0, 1029275.3ms, 71.2) EventNode(side_out, 162.5, 1030986.8ms, 4.0) EventNode(center_in, 163.0, 1031462.8ms, 11.0)
# 163 center_in initiate
# 163 center_in initiate True
# EventNode(outcome, 163.0, 1031976.3ms, 71.2) EventNode(side_out, 163.5, 1033022.6ms, 4.0) EventNode(center_in, 164.0, 1033631.0ms, 11.0)
# 164 center_in initiate
# 164 center_in initiate True
# EventNode(outcome, 164.0, 1034399.4ms, 71.2) EventNode(side_out, 164.5, 1035434.9ms, 4.0) EventNode(center_in, 165.0, 1036097.9ms, 11.0)
# 165 center_in initiate
# 165 center_in initiate True
# EventNode(outcome, 165.0, 1036588.4ms, 71.2) EventNode(side_out, 165.5, 1039406.4ms, 4.0) EventNode(center_in, 166.0, 1039827.4ms, 11.0)
# 166 center_in initiate
# 166 center_in initiate True
# EventNode(outcome, 166.0, 1040381.5ms, 71.2) EventNode(side_out, 166.5, 1043040.3ms, 4.0) EventNode(center_in, 167.0, 1043498.9ms, 11.0)
# 167 center_in initiate
# 167 center_in initiate True
# EventNode(outcome, 167.0, 1044212.5ms, 71.2) EventNode(side_out, 167.5, 1046367.2ms, 4.0) EventNode(center_in, 168.0, 1047004.6ms, 11.0)
# 168 center_in initiate
# 168 center_in initiate True
# EventNode(outcome, 168.0, 1047571.5ms, 71.2) EventNode(side_out, 168.5, 1049656.2ms, 4.0) EventNode(center_in, 169.0, 1050114.2ms, 11.0)
# 169 center_in initiate
# 169 center_in initiate True
# EventNode(outcome, 169.0, 1050679.6ms, 71.2) EventNode(side_out, 169.5, 1052903.4ms, 4.0) EventNode(center_in, 170.0, 1053477.5ms, 11.0)
# 170 center_in initiate
# 170 center_in initiate True
# EventNode(outcome, 170.0, 1054253.6ms, 71.2) EventNode(side_out, 170.5, 1058722.1ms, 4.0) EventNode(center_in, 171.0, 1059366.2ms, 11.0)
# 171 center_in
# center_in
# center_out
# 171 center_in initiate True
# EventNode(outcome, 171.0, 1059927.7ms, 72.0) EventNode(side_out, 171.5, 1060560.8ms, 4.0) EventNode(center_in, 171.5, 1061251.4ms, 1.0)
# 172 center_in
# center_in
# center_out
# side_in
# 172 side_in  False
# NO bueno
# 172 center_in initiate
# 172 center_in initiate True
# 173 center_in initiate
# 173 center_in initiate True
# EventNode(outcome, 173.0, 1066174.4ms, 71.2) EventNode(side_out, 173.5, 1069154.2ms, 6.0) EventNode(center_in, 174.0, 1069639.7ms, 11.0)
# 174 center_in initiate
# 174 center_in initiate True
# EventNode(outcome, 174.0, 1070065.8ms, 71.2) EventNode(side_out, 174.5, 1072141.0ms, 6.0) EventNode(center_in, 175.0, 1072665.6ms, 11.0)
# 175 center_in initiate
# 175 center_in initiate True
# EventNode(outcome, 175.0, 1073076.1ms, 71.2) EventNode(side_out, 175.5, 1075198.8ms, 6.0) EventNode(center_in, 176.0, 1075761.9ms, 11.0)
# 176 center_in initiate
# 176 center_in initiate True
# EventNode(outcome, 176.0, 1076182.9ms, 71.2) EventNode(side_out, 176.5, 1076683.0ms, 6.0) EventNode(center_in, 177.0, 1077915.1ms, 11.0)
# 177 center_in initiate
# 177 center_in initiate True
# EventNode(outcome, 177.0, 1078405.7ms, 71.2) EventNode(side_out, 177.5, 1079230.2ms, 6.0) EventNode(center_in, 178.0, 1079663.8ms, 11.0)
# 178 center_in
# center_in
# center_out
# 178 center_in initiate True
# EventNode(outcome, 178.0, 1080107.8ms, 71.2) EventNode(side_out, 178.5, 1085146.4ms, 6.0) EventNode(center_in, 178.5, 1085785.4ms, 1.0)
# 179 center_in initiate
# 179 center_in initiate True
# EventNode(outcome, 179.0, 1086586.0ms, 71.2) EventNode(side_out, 179.5, 1087710.1ms, 6.0) EventNode(center_in, 180.0, 1088384.2ms, 11.0)
# 180 center_in
# center_in
# center_out
# 180 center_in initiate True
# EventNode(outcome, 180.0, 1088838.7ms, 71.2) EventNode(side_out, 180.5, 1093843.8ms, 6.0) EventNode(center_in, 180.5, 1094582.8ms, 1.0)
# 181 center_in initiate
# 181 center_in initiate True
# EventNode(outcome, 181.0, 1095478.4ms, 71.2) EventNode(side_out, 181.5, 1100540.0ms, 6.0) EventNode(center_in, 182.0, 1101230.0ms, 11.0)
# 182 center_in
# center_in
# center_out
# 182 center_in initiate True
# EventNode(outcome, 182.0, 1101696.6ms, 71.2) EventNode(side_out, 182.5, 1107376.2ms, 6.0) EventNode(center_in, 182.5, 1107806.2ms, 1.0)
# 183 center_in initiate
# 183 center_in initiate True
# EventNode(outcome, 183.0, 1108696.3ms, 71.2) EventNode(side_out, 183.5, 1111237.1ms, 6.0) EventNode(center_in, 184.0, 1111768.6ms, 11.0)
# 184 center_in initiate
# 184 center_in initiate True
# EventNode(outcome, 184.0, 1112257.2ms, 71.2) EventNode(side_out, 184.5, 1113685.8ms, 6.0) EventNode(center_in, 185.0, 1114358.9ms, 11.0)
# 185 center_in initiate
# 185 center_in initiate True
# EventNode(outcome, 185.0, 1114816.5ms, 71.2) EventNode(side_out, 185.5, 1116238.1ms, 6.0) EventNode(center_in, 186.0, 1116736.7ms, 11.0)
# 186 center_in
# center_in
# center_out
# 186 center_in initiate True
# EventNode(outcome, 186.0, 1117150.7ms, 72.0) EventNode(side_out, 186.5, 1117550.2ms, 6.0) EventNode(center_in, 186.5, 1118262.3ms, 1.0)
# 187 center_in initiate
# 187 center_in initiate True
# 188 center_in initiate
# 188 center_in initiate True
# EventNode(outcome, 188.0, 1130890.6ms, 71.2) EventNode(side_out, 188.5, 1133076.7ms, 4.0) EventNode(center_in, 189.0, 1133536.2ms, 11.0)
# 189 center_in initiate
# 189 center_in initiate True
# EventNode(outcome, 189.0, 1134081.7ms, 71.2) EventNode(side_out, 189.5, 1139005.8ms, 4.0) EventNode(center_in, 190.0, 1139526.8ms, 11.0)
# 190 center_in initiate
# 190 center_in initiate True
# EventNode(outcome, 190.0, 1140073.7ms, 71.2) EventNode(side_out, 190.5, 1140793.7ms, 4.0) EventNode(center_in, 191.0, 1141359.2ms, 11.0)
# 191 center_in initiate
# 191 center_in initiate True
# EventNode(outcome, 191.0, 1142312.8ms, 71.2) EventNode(side_out, 191.5, 1145086.9ms, 4.0) EventNode(center_in, 192.0, 1145652.4ms, 11.0)
# 192 center_in initiate
# 192 center_in initiate True
# EventNode(outcome, 192.0, 1146208.8ms, 71.2) EventNode(side_out, 192.5, 1148859.9ms, 4.0) EventNode(center_in, 193.0, 1149352.4ms, 11.0)
# 193 center_in initiate
# 193 center_in initiate True
# EventNode(outcome, 193.0, 1149849.9ms, 71.2) EventNode(side_out, 193.5, 1152186.9ms, 4.0) EventNode(center_in, 194.0, 1152760.4ms, 11.0)
# 194 center_in initiate
# 194 center_in initiate True
# EventNode(outcome, 194.0, 1153312.9ms, 71.2) EventNode(side_out, 194.5, 1155948.6ms, 4.0) EventNode(center_in, 195.0, 1156506.0ms, 11.0)
# 195 center_in initiate
# 195 center_in initiate True
# EventNode(outcome, 195.0, 1157105.0ms, 71.2) EventNode(side_out, 195.5, 1159484.5ms, 4.0) EventNode(center_in, 196.0, 1160051.5ms, 11.0)
# 196 center_in initiate
# 196 center_in initiate True
# EventNode(outcome, 196.0, 1160600.0ms, 71.2) EventNode(side_out, 196.5, 1163172.6ms, 4.0) EventNode(center_in, 197.0, 1163582.1ms, 11.0)
# 197 center_in initiate
# 197 center_in initiate True
# EventNode(outcome, 197.0, 1164137.1ms, 71.2) EventNode(side_out, 197.5, 1166415.1ms, 4.0) EventNode(center_in, 198.0, 1166974.1ms, 11.0)
# 198 center_in initiate
# 198 center_in initiate True
# EventNode(outcome, 198.0, 1167616.1ms, 71.2) EventNode(side_out, 198.5, 1169938.3ms, 4.0) EventNode(center_in, 199.0, 1170549.8ms, 11.0)
# 199 center_in initiate
# 199 center_in initiate True
# EventNode(outcome, 199.0, 1171117.2ms, 71.2) EventNode(side_out, 199.5, 1172513.5ms, 4.0) EventNode(center_in, 200.0, 1173188.1ms, 11.0)
# 200 center_in initiate
# 200 center_in initiate True
# EventNode(outcome, 200.0, 1173807.2ms, 71.2) EventNode(side_out, 200.5, 1175814.7ms, 4.0) EventNode(center_in, 201.0, 1176727.2ms, 11.0)
# 201 center_in initiate
# 201 center_in initiate True
# EventNode(outcome, 201.0, 1177302.2ms, 71.2) EventNode(side_out, 201.5, 1177943.2ms, 4.0) EventNode(center_in, 202.0, 1178660.7ms, 11.0)
# 202 center_in initiate
# 202 center_in initiate True
# EventNode(outcome, 202.0, 1179809.6ms, 71.1) EventNode(side_out, 202.5, 1179888.1ms, 4.0) EventNode(center_in, 203.0, 1187970.8ms, 11.0)
# 203 center_in initiate
# 203 center_in initiate True
# 204 center_in initiate
# 204 center_in initiate True
# EventNode(outcome, 204.0, 1191537.2ms, 71.1) EventNode(side_out, 204.5, 1192523.6ms, 4.0) EventNode(center_in, 205.0, 1193174.1ms, 11.0)
# 205 center_in
# center_in
# center_out
# 205 center_in initiate True
# EventNode(outcome, 205.0, 1193866.6ms, 71.1) EventNode(side_out, 205.5, 1194747.0ms, 4.0) EventNode(center_in, 205.5, 1195259.0ms, 1.0)
# 206 center_in initiate
# 206 center_in initiate True
# EventNode(outcome, 206.0, 1196158.5ms, 71.2) EventNode(side_out, 206.5, 1199042.0ms, 4.0) EventNode(center_in, 207.0, 1199515.5ms, 11.0)
# 207 center_in initiate
# 207 center_in initiate True
# EventNode(outcome, 207.0, 1200205.6ms, 71.2) EventNode(side_out, 207.5, 1201350.3ms, 4.0) EventNode(center_in, 208.0, 1201866.2ms, 11.0)
# 208 center_in
# center_in
# center_out
# side_in
# 208 side_in  False
# NO bueno
# 208 center_in initiate
# 208 center_in initiate True
# 209 center_in
# center_in
# center_out
# 209 center_in initiate True
# EventNode(outcome, 209.0, 1205927.5ms, 72.0) EventNode(side_out, 209.5, 1206331.4ms, 4.0) EventNode(center_in, 209.5, 1207328.4ms, 1.0)
# 210 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 210 side_in  False
# NO bueno
# 210 center_in initiate
# 210 center_in initiate True
# 211 center_in initiate
# 211 center_in initiate True
# EventNode(outcome, 211.0, 1212309.8ms, 71.2) EventNode(side_out, 211.5, 1214907.8ms, 6.0) EventNode(center_in, 212.0, 1215554.2ms, 11.0)
# 212 center_in initiate
# 212 center_in initiate True
# EventNode(outcome, 212.0, 1215985.2ms, 71.2) EventNode(side_out, 212.5, 1220540.1ms, 6.0) EventNode(center_in, 213.0, 1221003.1ms, 11.0)
# 213 center_in initiate
# 213 center_in initiate True
# EventNode(outcome, 213.0, 1221436.1ms, 71.2) EventNode(side_out, 213.5, 1224695.0ms, 6.0) EventNode(center_in, 214.0, 1225149.0ms, 11.0)
# 214 center_in initiate
# 214 center_in initiate True
# EventNode(outcome, 214.0, 1225574.0ms, 71.2) EventNode(side_out, 214.5, 1226604.5ms, 6.0) EventNode(center_in, 215.0, 1227062.0ms, 11.0)
# 215 center_in initiate
# 215 center_in initiate True
# EventNode(outcome, 215.0, 1227573.5ms, 71.2) EventNode(side_out, 215.5, 1229508.9ms, 6.0) EventNode(center_in, 216.0, 1229941.9ms, 11.0)
# 216 center_in initiate
# 216 center_in initiate True
# EventNode(outcome, 216.0, 1230469.9ms, 71.2) EventNode(side_out, 216.5, 1232890.9ms, 6.0) EventNode(center_in, 217.0, 1233514.8ms, 11.0)
# 217 center_in
# center_in
# center_out
# side_in
# 217 side_in  False
# NO bueno
# 217 center_in initiate
# 217 center_in initiate True
# 218 center_in initiate
# 218 center_in initiate True
# EventNode(outcome, 218.0, 1236831.8ms, 71.2) EventNode(side_out, 218.5, 1238960.2ms, 6.0) EventNode(center_in, 219.0, 1239856.7ms, 11.0)
# 219 center_in initiate
# 219 center_in initiate True
# EventNode(outcome, 219.0, 1240361.2ms, 71.2) EventNode(side_out, 219.5, 1242551.7ms, 6.0) EventNode(center_in, 220.0, 1243051.1ms, 11.0)
# 220 center_in
# center_in
# center_out
# side_in
# 220 side_in  False
# NO bueno
# 220 center_in initiate
# 220 center_in initiate True
# 221 center_in initiate
# 221 center_in initiate True
# 222 center_in
# center_in
# center_out
# side_in
# 222 side_in  False
# NO bueno
# 222 center_in initiate
# 222 center_in initiate True
# 223 center_in
# center_in
# center_out
# side_in
# 223 side_in  False
# NO bueno
# 223 center_in initiate
# 223 center_in initiate True
# 224 center_in initiate
# 224 center_in initiate True
# EventNode(outcome, 224.0, 1256436.3ms, 71.2) EventNode(side_out, 224.5, 1258798.8ms, 4.0) EventNode(center_in, 225.0, 1259430.3ms, 11.0)
# 225 center_in initiate
# 225 center_in initiate True
# EventNode(outcome, 225.0, 1259903.3ms, 71.2) EventNode(side_out, 225.5, 1262142.3ms, 4.0) EventNode(center_in, 226.0, 1262610.3ms, 11.0)
# 226 center_in initiate
# 226 center_in initiate True
# EventNode(outcome, 226.0, 1263122.3ms, 71.2) EventNode(side_out, 226.5, 1266345.6ms, 4.0) EventNode(center_in, 227.0, 1266798.6ms, 11.0)
# 227 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 227 side_in  False
# NO bueno
# 227 center_in initiate
# 227 center_in initiate True
# 228 center_in initiate
# 228 center_in initiate True
# EventNode(outcome, 228.0, 1270502.4ms, 71.2) EventNode(side_out, 228.5, 1273197.0ms, 4.0) EventNode(center_in, 229.0, 1273722.0ms, 11.0)
# 229 center_in
# center_in
# center_out
# 229 center_in initiate True
# EventNode(outcome, 229.0, 1274200.0ms, 71.1) EventNode(side_out, 229.5, 1274963.0ms, 4.0) EventNode(center_in, 229.5, 1275440.5ms, 1.0)
# 230 center_in
# center_in
# center_out
# 230 center_in initiate True
# EventNode(outcome, 230.0, 1276542.5ms, 72.0) EventNode(side_out, 230.5, 1277134.6ms, 6.0) EventNode(center_in, 230.5, 1277559.1ms, 1.0)
# 231 center_in
# center_in
# center_out
# side_in
# 231 side_in  False
# NO bueno
# 231 center_in initiate
# 231 center_in initiate True
# 232 center_in
# center_in
# center_out
# center_in
# center_out
# 232 center_in initiate True
# EventNode(outcome, 232.0, 1281767.2ms, 71.1) EventNode(side_out, 232.5, 1282333.2ms, 4.0) EventNode(center_in, 232.5, 1283275.2ms, 1.0)
# 233 center_in initiate
# 233 center_in initiate True
# EventNode(outcome, 233.0, 1284135.7ms, 71.2) EventNode(side_out, 233.5, 1287522.3ms, 4.0) EventNode(center_in, 234.0, 1288058.8ms, 11.0)
# 234 center_in initiate
# 234 center_in initiate True
# EventNode(outcome, 234.0, 1288804.7ms, 71.2) EventNode(side_out, 234.5, 1292335.6ms, 4.0) EventNode(center_in, 235.0, 1292987.6ms, 11.0)
# 235 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 235 side_in  False
# NO bueno
# 235 center_in initiate
# 235 center_in initiate True
# 236 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 236 side_in  False
# NO bueno
# 236 center_in initiate
# 236 center_in initiate True
# 237 center_in initiate
# 237 center_in initiate True
# EventNode(outcome, 237.0, 1304588.0ms, 71.1) EventNode(side_out, 237.5, 1305563.4ms, 4.0) EventNode(center_in, 238.0, 1306013.4ms, 11.0)
# 238 center_in initiate
# 238 center_in initiate True
# EventNode(outcome, 238.0, 1306670.9ms, 71.2) EventNode(side_out, 238.5, 1309888.6ms, 4.0) EventNode(center_in, 239.0, 1310321.1ms, 11.0)
# 239 center_in initiate
# 239 center_in initiate True
# EventNode(outcome, 239.0, 1311138.0ms, 71.2) EventNode(side_out, 239.5, 1313596.5ms, 4.0) EventNode(center_in, 240.0, 1314179.5ms, 11.0)
# 240 center_in initiate
# 240 center_in initiate True
# EventNode(outcome, 240.0, 1314707.0ms, 71.2) EventNode(side_out, 240.5, 1317088.6ms, 4.0) EventNode(center_in, 241.0, 1317587.6ms, 11.0)
# 241 center_in initiate
# 241 center_in initiate True
# EventNode(outcome, 241.0, 1318142.1ms, 71.2) EventNode(side_out, 241.5, 1321258.7ms, 4.0) EventNode(center_in, 242.0, 1322025.7ms, 11.0)
# 242 center_in initiate
# 242 center_in initiate True
# EventNode(outcome, 242.0, 1322556.3ms, 71.2) EventNode(side_out, 242.5, 1325011.3ms, 4.0) EventNode(center_in, 243.0, 1325443.3ms, 11.0)
# 243 center_in
# center_in
# center_out
# side_in
# 243 side_in  False
# NO bueno
# 243 center_in initiate
# 243 center_in initiate True
# 244 center_in initiate
# 244 center_in initiate True
# EventNode(outcome, 244.0, 1329210.3ms, 71.2) EventNode(side_out, 244.5, 1332016.0ms, 4.0) EventNode(center_in, 245.0, 1332491.9ms, 11.0)
# 245 center_in initiate
# 245 center_in initiate True
# EventNode(outcome, 245.0, 1333093.3ms, 71.2) EventNode(side_out, 245.5, 1336802.7ms, 4.0) EventNode(center_in, 246.0, 1337403.3ms, 11.0)
# 246 center_in initiate
# 246 center_in initiate True
# EventNode(outcome, 246.0, 1337968.3ms, 71.2) EventNode(side_out, 246.5, 1341062.5ms, 4.0) EventNode(center_in, 247.0, 1341680.7ms, 11.0)
# 247 center_in initiate
# 247 center_in initiate True
# EventNode(outcome, 247.0, 1342257.4ms, 71.1) EventNode(side_out, 247.5, 1348767.3ms, 4.0) EventNode(center_in, 248.0, 1352565.7ms, 11.0)
# 248 center_in initiate
# 248 center_in initiate True
# 249 center_in
# center_in
# center_out
# 249 center_in initiate True
# EventNode(outcome, 249.0, 1357061.3ms, 72.0) EventNode(side_out, 249.5, 1358047.7ms, 6.0) EventNode(center_in, 249.5, 1358527.4ms, 1.0)
# 250 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 250 side_in  False
# NO bueno
# 250 center_in
# center_in
# center_out
# 250 center_in initiate True
# 251 center_in initiate
# 251 center_in initiate True
# EventNode(outcome, 251.0, 1363460.7ms, 71.2) EventNode(side_out, 251.5, 1364807.2ms, 4.0) EventNode(center_in, 252.0, 1365279.2ms, 11.0)
# 252 center_in initiate
# 252 center_in initiate True
# EventNode(outcome, 252.0, 1365865.7ms, 71.2) EventNode(side_out, 252.5, 1369827.6ms, 4.0) EventNode(center_in, 253.0, 1370347.1ms, 11.0)
# 253 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 253 side_in  False
# NO bueno
# 253 center_in initiate
# 253 center_in initiate True
# 254 center_in
# center_in
# center_out
# side_in
# 254 side_in  False
# NO bueno
# 254 center_in initiate
# 254 center_in initiate True
# 255 center_in
# center_in
# center_out
# 255 center_in initiate True
# EventNode(outcome, 255.0, 1377538.4ms, 72.0) EventNode(side_out, 255.5, 1378722.9ms, 4.0) EventNode(center_in, 255.5, 1379107.9ms, 1.0)
# 256 center_in initiate
# 256 center_in initiate True
# EventNode(outcome, 256.0, 1380428.9ms, 71.2) EventNode(side_out, 256.5, 1381571.8ms, 6.0) EventNode(center_in, 257.0, 1382393.8ms, 11.0)
# 257 center_in initiate
# 257 center_in initiate True
# EventNode(outcome, 257.0, 1382825.3ms, 71.2) EventNode(side_out, 257.5, 1384410.8ms, 6.0) EventNode(center_in, 258.0, 1384956.3ms, 11.0)
# 258 center_in initiate
# 258 center_in initiate True
# EventNode(outcome, 258.0, 1385394.2ms, 71.2) EventNode(side_out, 258.5, 1385949.7ms, 6.0) EventNode(center_in, 259.0, 1386331.7ms, 11.0)
# 259 center_in initiate
# 259 center_in initiate True
# EventNode(outcome, 259.0, 1386731.2ms, 71.2) EventNode(side_out, 259.5, 1387525.7ms, 6.0) EventNode(center_in, 260.0, 1387941.2ms, 11.0)
# 260 center_in initiate
# 260 center_in initiate True
# EventNode(outcome, 260.0, 1388393.2ms, 71.2) EventNode(side_out, 260.5, 1391151.6ms, 6.0) EventNode(center_in, 261.0, 1391679.6ms, 11.0)
# 261 center_in initiate
# 261 center_in initiate True
# EventNode(outcome, 261.0, 1392039.1ms, 71.2) EventNode(side_out, 261.5, 1396154.5ms, 6.0) EventNode(center_in, 262.0, 1396760.0ms, 11.0)
# 262 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 262 side_in  False
# NO bueno
# 262 center_in initiate
# 262 center_in initiate True
# 263 center_in
# center_in
# center_out
# 263 center_in initiate True
# EventNode(outcome, 263.0, 1400069.9ms, 71.1) EventNode(side_out, 263.5, 1400338.4ms, 6.0) EventNode(center_in, 263.5, 1401085.9ms, 1.0)
# 264 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# 264 center_in initiate True
# EventNode(outcome, 264.0, 1402257.3ms, 71.1) EventNode(side_out, 264.5, 1402557.8ms, 6.0) EventNode(center_in, 264.5, 1403142.8ms, 1.0)
# 265 center_in initiate
# 265 center_in initiate True
# EventNode(outcome, 265.0, 1404539.8ms, 71.2) EventNode(side_out, 265.5, 1406573.2ms, 6.0) EventNode(center_in, 266.0, 1407065.2ms, 11.0)
# 266 center_in initiate
# 266 center_in initiate True
# EventNode(outcome, 266.0, 1407484.7ms, 71.2) EventNode(side_out, 266.5, 1410586.1ms, 6.0) EventNode(center_in, 267.0, 1411180.1ms, 11.0)
# 267 center_in initiate
# 267 center_in initiate True
# EventNode(outcome, 267.0, 1411605.1ms, 71.1) EventNode(side_out, 267.5, 1412532.1ms, 6.0) EventNode(center_in, 268.0, 1413398.6ms, 11.0)
# 268 center_in initiate
# 268 center_in initiate True
# EventNode(outcome, 268.0, 1413865.1ms, 71.2) EventNode(side_out, 268.5, 1418504.5ms, 6.0) EventNode(center_in, 269.0, 1419092.9ms, 11.0)
# 269 center_in
# center_in
# center_out
# center_in
# center_out
# 269 center_in initiate True
# EventNode(outcome, 269.0, 1419524.4ms, 71.1) EventNode(side_out, 269.5, 1419754.4ms, 6.0) EventNode(center_in, 269.5, 1420208.9ms, 1.0)
# 270 center_in initiate
# 270 center_in initiate True
# EventNode(outcome, 270.0, 1421358.4ms, 71.2) EventNode(side_out, 270.5, 1424645.3ms, 6.0) EventNode(center_in, 271.0, 1425135.3ms, 11.0)
# 271 center_in initiate
# 271 center_in initiate True
# EventNode(outcome, 271.0, 1425606.3ms, 71.2) EventNode(side_out, 271.5, 1429855.7ms, 6.0) EventNode(center_in, 272.0, 1430851.2ms, 11.0)
# 272 center_in initiate
# 272 center_in initiate True
# EventNode(outcome, 272.0, 1431325.2ms, 71.2) EventNode(side_out, 272.5, 1433465.6ms, 6.0) EventNode(center_in, 273.0, 1434171.1ms, 11.0)
# 273 center_in initiate
# 273 center_in initiate True
# EventNode(outcome, 273.0, 1434536.1ms, 71.2) EventNode(side_out, 273.5, 1437396.0ms, 6.0) EventNode(center_in, 274.0, 1438107.5ms, 11.0)
# 274 center_in initiate
# 274 center_in initiate True
# EventNode(outcome, 274.0, 1438539.5ms, 71.2) EventNode(side_out, 274.5, 1441487.4ms, 6.0) EventNode(center_in, 275.0, 1442607.4ms, 11.0)
# 275 center_in initiate
# 275 center_in initiate True
# EventNode(outcome, 275.0, 1443057.4ms, 71.2) EventNode(side_out, 275.5, 1446703.3ms, 6.0) EventNode(center_in, 276.0, 1447772.3ms, 11.0)
# 276 center_in initiate
# 276 center_in initiate True
# EventNode(outcome, 276.0, 1448252.8ms, 71.2) EventNode(side_out, 276.5, 1452132.7ms, 6.0) EventNode(center_in, 277.0, 1453369.1ms, 11.0)
# 277 center_in initiate
# 277 center_in initiate True
# EventNode(outcome, 277.0, 1453846.1ms, 71.2) EventNode(side_out, 277.5, 1456440.6ms, 6.0) EventNode(center_in, 278.0, 1457145.0ms, 11.0)
# 278 center_in
# center_in
# center_out
# 278 center_in initiate True
# EventNode(outcome, 278.0, 1457586.0ms, 71.1) EventNode(side_out, 278.5, 1458054.5ms, 6.0) EventNode(center_in, 278.5, 1458850.5ms, 1.0)
# 279 center_in initiate
# 279 center_in initiate True
# EventNode(outcome, 279.0, 1459761.5ms, 71.2) EventNode(side_out, 279.5, 1462950.9ms, 6.0) EventNode(center_in, 280.0, 1464142.9ms, 11.0)
# 280 center_in initiate
# 280 center_in initiate True
# EventNode(outcome, 280.0, 1464682.9ms, 71.2) EventNode(side_out, 280.5, 1466484.3ms, 6.0) EventNode(center_in, 281.0, 1466974.8ms, 11.0)
# 281 center_in
# center_in
# center_out
# center_in
# center_out
# 281 center_in initiate True
# EventNode(outcome, 281.0, 1467444.3ms, 71.2) EventNode(side_out, 281.5, 1468291.8ms, 6.0) EventNode(center_in, 281.5, 1468897.8ms, 1.0)
# 282 center_in initiate
# 282 center_in initiate True
# ...
# 1011 center_in initiate
# 1011 center_in initiate True
# EventNode(outcome, 1011.0, 5181358.5ms, 71.2) EventNode(side_out, 1011.5, 5182418.0ms, 6.0) EventNode(center_in, 1012.0, 5182839.0ms, 11.0)
# 1012 center_in initiate
# 1012 center_in initiate True
# EventNode(outcome, 1012.0, 5183295.5ms, 71.2) EventNode(side_out, 1012.5, 5184558.0ms, 6.0) EventNode(center_in, 1013.0, 5184990.5ms, 11.0)
# 1013 center_in initiate
# 1013 center_in initiate True
# EventNode(outcome, 1013.0, 5185438.0ms, 71.2) EventNode(side_out, 1013.5, 5185996.4ms, 6.0) EventNode(center_in, 1014.0, 5186404.9ms, 11.0)
# 1014 center_in initiate
# 1014 center_in initiate True
# EventNode(outcome, 1014.0, 5186843.9ms, 71.2) EventNode(side_out, 1014.5, 5190498.4ms, 6.0) EventNode(center_in, 1015.0, 5190966.8ms, 11.0)
# 1015 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 1015 side_in  False
# NO bueno
# 1015 center_in initiate
# 1015 center_in initiate True
# 1016 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 1016 side_in  False
# NO bueno
# 1016 center_in initiate
# 1016 center_in initiate True
# 1017 center_in
# center_in
# center_out
# side_in
# 1017 side_in  False
# NO bueno
# 1017 center_in initiate
# 1017 center_in initiate True
# 1018 center_in
# center_in
# center_out
# side_in
# 1018 side_in  False
# NO bueno
# 1018 center_in initiate
# 1018 center_in initiate True
# 1019 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 1019 side_in  False
# NO bueno
# 1019 center_in initiate
# 1019 center_in initiate True
# 1020 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 1020 side_in  False
# NO bueno
# 1020 center_in initiate
# 1020 center_in initiate True
# 1021 center_in initiate
# 1021 center_in initiate True
# EventNode(outcome, 1021.0, 5211257.4ms, 71.2) EventNode(side_out, 1021.5, 5213375.4ms, 6.0) EventNode(center_in, 1022.0, 5213852.9ms, 11.0)
# 1022 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 1022 side_in  False
# NO bueno
# 1022 center_in initiate
# 1022 center_in initiate True
# 1023 center_in
# center_in
# center_out
# center_in
# center_out
# 1023 center_in initiate True
# EventNode(outcome, 1023.0, 5217266.3ms, 72.0) EventNode(side_out, 1023.5, 5217828.8ms, 6.0) EventNode(center_in, 1023.5, 5218216.8ms, 1.0)
# 1024 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 1024 side_in  False
# NO bueno
# 1024 center_in initiate
# 1024 center_in initiate True
# 1025 center_in initiate
# 1025 center_in initiate True
# EventNode(outcome, 1025.0, 5222639.7ms, 71.2) EventNode(side_out, 1025.5, 5224406.4ms, 4.0) EventNode(center_in, 1026.0, 5224823.3ms, 11.0)
# 1026 center_in initiate
# 1026 center_in initiate True
# EventNode(outcome, 1026.0, 5225418.7ms, 71.2) EventNode(side_out, 1026.5, 5230016.9ms, 4.0) EventNode(center_in, 1027.0, 5230482.9ms, 11.0)
# 1027 center_in
# center_in
# center_out
# 1027 center_in initiate True
# EventNode(outcome, 1027.0, 5230984.9ms, 71.1) EventNode(side_out, 1027.5, 5231621.8ms, 4.0) EventNode(center_in, 1027.5, 5232151.8ms, 1.0)
# 1028 center_in initiate
# 1028 center_in initiate True
# EventNode(outcome, 1028.0, 5232809.8ms, 71.2) EventNode(side_out, 1028.5, 5235209.0ms, 4.0) EventNode(center_in, 1029.0, 5235611.0ms, 11.0)
# 1029 center_in initiate
# 1029 center_in initiate True
# EventNode(outcome, 1029.0, 5236147.0ms, 71.2) EventNode(side_out, 1029.5, 5237896.2ms, 4.0) EventNode(center_in, 1030.0, 5238390.3ms, 11.0)
# 1030 center_in initiate
# 1030 center_in initiate True
# EventNode(outcome, 1030.0, 5238842.8ms, 71.2) EventNode(side_out, 1030.5, 5240644.3ms, 4.0) EventNode(center_in, 1031.0, 5241150.8ms, 11.0)
# 1031 center_in
# center_in
# center_out
# side_in
# 1031 side_in  False
# NO bueno
# 1031 center_in initiate
# 1031 center_in initiate True
# 1032 center_in initiate
# 1032 center_in initiate True
# EventNode(outcome, 1032.0, 5310138.8ms, 71.2) EventNode(side_out, 1032.5, 5310776.7ms, 4.0) EventNode(center_in, 1033.0, 5311306.2ms, 11.0)
# 1033 center_in
# center_in
# center_out
# side_in
# 1033 side_in  False
# NO bueno
# 1033 center_in initiate
# 1033 center_in initiate True
# 1034 center_in initiate
# 1034 center_in initiate True
# EventNode(outcome, 1034.0, 5315704.6ms, 72.0) EventNode(side_out, 1034.5, 5317838.0ms, 6.0) EventNode(center_in, 1035.0, 5318668.5ms, 11.0)
# 1035 center_in
# center_in
# center_out
# 1035 center_in initiate True
# EventNode(outcome, 1035.0, 5319526.9ms, 71.2) EventNode(side_out, 1035.5, 5322290.7ms, 4.0) EventNode(center_in, 1035.5, 5322753.6ms, 1.0)
# 1036 center_in initiate
# 1036 center_in initiate True
# EventNode(outcome, 1036.0, 5324022.0ms, 71.2) EventNode(side_out, 1036.5, 5325140.0ms, 4.0) EventNode(center_in, 1037.0, 5325609.0ms, 11.0)
# 1037 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 1037 side_in  False
# NO bueno
# 1037 center_in initiate
# 1037 center_in initiate True
# 1038 center_in initiate
# 1038 center_in initiate True
# EventNode(outcome, 1038.0, 5329800.0ms, 71.2) EventNode(side_out, 1038.5, 5331700.2ms, 4.0) EventNode(center_in, 1039.0, 5332119.2ms, 11.0)
# 1039 center_in initiate
# 1039 center_in initiate True
# EventNode(outcome, 1039.0, 5332592.2ms, 71.2) EventNode(side_out, 1039.5, 5334522.7ms, 4.0) EventNode(center_in, 1040.0, 5334933.2ms, 11.0)
# 1040 center_in
# center_in
# center_out
# side_in
# 1040 side_in  False
# NO bueno
# 1040 center_in initiate
# 1040 center_in initiate True
# 1041 center_in initiate
# 1041 center_in initiate True
# EventNode(outcome, 1041.0, 5339209.1ms, 71.2) EventNode(side_out, 1041.5, 5340308.0ms, 4.0) EventNode(center_in, 1042.0, 5340773.5ms, 11.0)
# 1042 center_in initiate
# 1042 center_in initiate True
# 1043 center_in initiate
# 1043 center_in initiate True
# 1044 center_in initiate
# 1044 center_in initiate True
# EventNode(outcome, 1044.0, 5347760.4ms, 71.2) EventNode(side_out, 1044.5, 5348373.0ms, 4.0) EventNode(center_in, 1045.0, 5348718.1ms, 11.0)
# 1045 center_in initiate
# 1045 center_in initiate True
# EventNode(outcome, 1045.0, 5349730.3ms, 71.2) EventNode(side_out, 1045.5, 5351808.3ms, 4.0) EventNode(center_in, 1046.0, 5352216.8ms, 11.0)
# 1046 center_in initiate
# 1046 center_in initiate True
# EventNode(outcome, 1046.0, 5352805.3ms, 71.2) EventNode(side_out, 1046.5, 5355773.0ms, 4.0) EventNode(center_in, 1047.0, 5356171.4ms, 11.0)
# 1047 center_in initiate
# 1047 center_in initiate True
# EventNode(outcome, 1047.0, 5356717.4ms, 71.2) EventNode(side_out, 1047.5, 5359051.6ms, 4.0) EventNode(center_in, 1048.0, 5359419.5ms, 11.0)
# 1048 center_in initiate
# 1048 center_in initiate True
# EventNode(outcome, 1048.0, 5360018.4ms, 71.2) EventNode(side_out, 1048.5, 5362413.3ms, 4.0) EventNode(center_in, 1049.0, 5362952.9ms, 11.0)
# 1049 center_in initiate
# 1049 center_in initiate True
# EventNode(outcome, 1049.0, 5363546.5ms, 71.2) EventNode(side_out, 1049.5, 5365819.6ms, 4.0) EventNode(center_in, 1050.0, 5366243.1ms, 11.0)
# 1050 center_in initiate
# 1050 center_in initiate True
# EventNode(outcome, 1050.0, 5366873.5ms, 71.2) EventNode(side_out, 1050.5, 5368966.1ms, 4.0) EventNode(center_in, 1051.0, 5369351.1ms, 11.0)
# 1051 center_in
# center_in
# center_out
# side_in
# 1051 side_in  False
# NO bueno
# 1051 center_in initiate
# 1051 center_in initiate True
# 1052 center_in initiate
# 1052 center_in initiate True
# EventNode(outcome, 1052.0, 5373419.8ms, 71.2) EventNode(side_out, 1052.5, 5375987.0ms, 6.0) EventNode(center_in, 1053.0, 5376464.5ms, 11.0)
# 1053 center_in initiate
# 1053 center_in initiate True
# EventNode(outcome, 1053.0, 5377026.0ms, 71.2) EventNode(side_out, 1053.5, 5381635.3ms, 6.0) EventNode(center_in, 1054.0, 5382500.8ms, 11.0)
# 1054 center_in initiate
# 1054 center_in initiate True
# EventNode(outcome, 1054.0, 5382954.3ms, 71.2) EventNode(side_out, 1054.5, 5384384.9ms, 6.0) EventNode(center_in, 1055.0, 5384825.4ms, 11.0)
# 1055 center_in initiate
# 1055 center_in initiate True
# EventNode(outcome, 1055.0, 5385249.0ms, 71.2) EventNode(side_out, 1055.5, 5386809.0ms, 6.0) EventNode(center_in, 1056.0, 5387283.1ms, 11.0)
# 1056 center_in initiate
# 1056 center_in initiate True
# EventNode(outcome, 1056.0, 5387732.6ms, 71.2) EventNode(side_out, 1056.5, 5388129.6ms, 6.0) EventNode(center_in, 1057.0, 5388775.2ms, 11.0)
# 1057 center_in initiate
# 1057 center_in initiate True
# EventNode(outcome, 1057.0, 5389203.2ms, 71.2) EventNode(side_out, 1057.5, 5389752.7ms, 6.0) EventNode(center_in, 1058.0, 5390134.2ms, 11.0)
# 1058 center_in initiate
# 1058 center_in initiate True
# EventNode(outcome, 1058.0, 5390526.2ms, 71.2) EventNode(side_out, 1058.5, 5393031.9ms, 6.0) EventNode(center_in, 1059.0, 5393535.4ms, 11.0)
# 1059 center_in initiate
# 1059 center_in initiate True
# EventNode(outcome, 1059.0, 5394156.9ms, 71.2) EventNode(side_out, 1059.5, 5396247.6ms, 6.0) EventNode(center_in, 1060.0, 5396703.6ms, 11.0)
# 1060 center_in
# center_in
# center_out
# 1060 center_in initiate True
# EventNode(outcome, 1060.0, 5397464.1ms, 71.1) EventNode(side_out, 1060.5, 5397815.6ms, 6.0) EventNode(center_in, 1060.5, 5398568.2ms, 1.0)
# 1061 center_in
# center_in
# center_out
# 1061 center_in initiate True
# EventNode(outcome, 1061.0, 5399809.2ms, 71.2) EventNode(side_out, 1061.5, 5402132.4ms, 6.0) EventNode(center_in, 1061.5, 5402784.4ms, 1.0)
# 1062 center_in initiate
# 1062 center_in initiate True
# EventNode(outcome, 1062.0, 5403915.0ms, 71.2) EventNode(side_out, 1062.5, 5405683.1ms, 6.0) EventNode(center_in, 1063.0, 5406213.6ms, 11.0)
# 1063 center_in
# center_in
# center_out
# side_in
# 1063 side_in  False
# NO bueno
# 1063 center_in initiate
# 1063 center_in initiate True
# 1064 center_in
# center_in
# center_out
# 1064 center_in initiate True
# EventNode(outcome, 1064.0, 5409250.2ms, 71.1) EventNode(side_out, 1064.5, 5409452.3ms, 6.0) EventNode(center_in, 1064.5, 5410000.3ms, 1.0)
# 1065 center_in
# center_in
# center_out
# side_in
# 1065 side_in  False
# NO bueno
# 1065 center_in initiate
# 1065 center_in initiate True
# 1066 center_in initiate
# 1066 center_in initiate True
# EventNode(outcome, 1066.0, 5415850.6ms, 71.2) EventNode(side_out, 1066.5, 5418536.7ms, 6.0) EventNode(center_in, 1067.0, 5419065.8ms, 11.0)
# 1067 center_in initiate
# 1067 center_in initiate True
# EventNode(outcome, 1067.0, 5419481.8ms, 71.2) EventNode(side_out, 1067.5, 5423404.0ms, 6.0) EventNode(center_in, 1068.0, 5423952.0ms, 11.0)
# 1068 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 1068 side_in  False
# NO bueno
# 1068 center_in initiate
# 1068 center_in initiate True
# 1069 center_in initiate
# 1069 center_in initiate True
# EventNode(outcome, 1069.0, 5427188.7ms, 71.2) EventNode(side_out, 1069.5, 5429139.8ms, 6.0) EventNode(center_in, 1070.0, 5429577.8ms, 11.0)
# 1070 center_in initiate
# 1070 center_in initiate True
# EventNode(outcome, 1070.0, 5430869.9ms, 71.2) EventNode(side_out, 1070.5, 5432818.5ms, 6.0) EventNode(center_in, 1071.0, 5433298.5ms, 11.0)
# 1071 center_in
# center_in
# center_out
# side_in
# 1071 side_in  False
# NO bueno
# 1071 center_in initiate
# 1071 center_in initiate True
# 1072 center_in initiate
# 1072 center_in initiate True
# EventNode(outcome, 1072.0, 5436215.7ms, 71.2) EventNode(side_out, 1072.5, 5438265.3ms, 6.0) EventNode(center_in, 1073.0, 5438725.8ms, 11.0)
# 1073 center_in
# center_in
# center_out
# 1073 center_in initiate True
# EventNode(outcome, 1073.0, 5439163.8ms, 71.2) EventNode(side_out, 1073.5, 5442828.0ms, 6.0) EventNode(center_in, 1073.5, 5443337.1ms, 1.0)
# 1074 center_in initiate
# 1074 center_in initiate True
# EventNode(outcome, 1074.0, 5444337.6ms, 71.2) EventNode(side_out, 1074.5, 5447079.8ms, 6.0) EventNode(center_in, 1075.0, 5449083.9ms, 11.0)
# 1075 center_in
# center_in
# center_out
# 1075 center_in initiate True
# EventNode(outcome, 1075.0, 5449538.9ms, 71.1) EventNode(side_out, 1075.5, 5450013.4ms, 6.0) EventNode(center_in, 1075.5, 5450771.0ms, 1.0)
# 1076 center_in
# center_in
# center_out
# center_in
# center_out
# side_in
# 1076 side_in  False
# NO bueno
# 1076 center_in initiate
# 1076 center_in initiate True
# 1077 center_in
# center_in
# center_out
# 1077 center_in initiate True
# EventNode(outcome, 1077.0, 5455145.7ms, 72.0) EventNode(side_out, 1077.5, 5455701.7ms, 4.0) EventNode(center_in, 1077.5, 5456658.3ms, 1.0)
# 1078 center_in
# center_in
# center_out
# side_in
# 1078 side_in  False
# NO bueno
# 1078 center_in initiate
# 1078 center_in initiate True
# 1079 center_in initiate
# 1079 center_in initiate True
# EventNode(outcome, 1079.0, 5465201.2ms, 72.0) EventNode(side_out, 1079.5, 5466102.3ms, 4.0) EventNode(center_in, 1080.0, 5466561.8ms, 11.0)
# 1080 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# side_in
# 1080 side_in  False
# NO bueno
# 1080 center_in initiate
# 1080 center_in initiate True
# 1081 center_in initiate
# 1081 center_in initiate True
# EventNode(outcome, 1081.0, 5470198.0ms, 71.2) EventNode(side_out, 1081.5, 5472084.1ms, 6.0) EventNode(center_in, 1082.0, 5472475.1ms, 11.0)
# 1082 center_in
# center_in
# center_out
# 1082 center_in initiate True
# EventNode(outcome, 1082.0, 5472849.1ms, 71.2) EventNode(side_out, 1082.5, 5473348.7ms, 6.0) EventNode(center_in, 1082.5, 5473724.7ms, 1.0)
# 1083 center_in initiate
# 1083 center_in initiate True
# EventNode(outcome, 1083.0, 5474396.2ms, 71.2) EventNode(side_out, 1083.5, 5477788.9ms, 6.0) EventNode(center_in, 1084.0, 5478391.9ms, 11.0)
# 1084 center_in
# center_in
# center_out
# side_in
# 1084 side_in  False
# NO bueno
# 1084 center_in initiate
# 1084 center_in initiate True
# 1085 center_in
# center_in
# center_out
# center_in
# center_out
# 1085 center_in initiate True
# EventNode(outcome, 1085.0, 5481574.6ms, 72.0) EventNode(side_out, 1085.5, 5481963.1ms, 6.0) EventNode(center_in, 1085.5, 5482364.7ms, 1.0)
# 1086 center_in
# center_in
# center_out
# center_in
# center_out
# center_in
# center_out
# 1086 center_in initiate True
# EventNode(outcome, 1086.0, 5483605.7ms, 72.0) EventNode(side_out, 1086.5, 5483837.7ms, 6.0) EventNode(center_in, 1086.5, 5484264.3ms, 1.0)
# 1087 center_in
# center_in
# center_out
# side_in
# 1087 side_in  False
# NO bueno
# 1087 center_in initiate
# 1087 center_in initiate True
# 1088 center_in
# center_in
# center_out
# 1088 center_in initiate True
# EventNode(outcome, 1088.0, 5488854.5ms, 72.0) EventNode(side_out, 1088.5, 5489208.5ms, 6.0) EventNode(center_in, 1088.5, 5489862.1ms, 1.0)
# 1089 center_in initiate
# 1089 center_in initiate True
# EventNode(outcome, 1089.0, 5490957.1ms, 71.2) EventNode(side_out, 1089.5, 5492878.8ms, 4.0) EventNode(center_in, 1090.0, 5493294.4ms, 11.0)
# 1090 center_in
# center_in
# center_out
# 1090 center_in initiate True
# EventNode(outcome, 1090.0, 5493800.9ms, 71.1) EventNode(side_out, 1090.5, 5494609.0ms, 4.0) EventNode(center_in, 1090.5, 5495035.6ms, 1.0)
# 1091 center_in initiate
# 1091 center_in initiate True
# EventNode(outcome, 1091.0, 5495918.2ms, 71.2) EventNode(side_out, 1091.5, 5499439.8ms, 4.0) EventNode(center_in, 1092.0, 5499944.8ms, 11.0)
# 1092 center_in initiate
# 1092 center_in initiate True
# EventNode(outcome, 1092.0, 5500597.3ms, 71.2) EventNode(side_out, 1092.5, 5506220.4ms, 4.0) EventNode(center_in, 1093.0, 5506628.4ms, 11.0)
# 1093 center_in initiate
# 1093 center_in initiate True
# EventNode(outcome, 1093.0, 5507155.3ms, 71.2) EventNode(side_out, 1093.5, 5509368.4ms, 4.0) EventNode(center_in, 1094.0, 5509836.9ms, 11.0)
# 1094 center_in initiate
# 1094 center_in initiate True
# EventNode(outcome, 1094.0, 5510291.4ms, 71.2) EventNode(side_out, 1094.5, 5513679.1ms, 4.0) EventNode(center_in, 1095.0, 5514176.1ms, 11.0)
# 1095 center_in initiate
# 1095 center_in initiate True
# EventNode(outcome, 1095.0, 5514633.5ms, 71.2) EventNode(side_out, 1095.5, 5516721.0ms, 4.0) EventNode(center_in, 1096.0, 5517205.5ms, 11.0)
# 1096 center_in initiate
# 1096 center_in initiate True
# EventNode(outcome, 1096.0, 5517733.5ms, 71.2) EventNode(side_out, 1096.5, 5522859.2ms, 4.0) EventNode(center_in, 1097.0, 5525386.6ms, 11.0)
# 1097 center_in initiate
# 1097 center_in initiate True
# EventNode(outcome, 1097.0, 5525945.6ms, 71.2) EventNode(side_out, 1097.5, 5530289.7ms, 4.0) EventNode(center_in, 1098.0, 5530789.7ms, 11.0)
# 1098 center_in initiate
# 1098 center_in initiate True
# EventNode(outcome, 1098.0, 5531334.8ms, 71.2) EventNode(side_out, 1098.5, 5533488.3ms, 4.0) EventNode(center_in, 1099.0, 5534124.3ms, 11.0)

# %%
for c in np.unique(bmat.choice_sides):
    print(np.sum(bmat.choice_sides == c))
# Out:
# 1
# 549
# 549

# %%
np.sum(bmat.struct_complexity)
# Out:
# 393

# %%
np.sum(bmat.exp_complexity)
# Out:
# 284
